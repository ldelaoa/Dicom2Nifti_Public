# %%
import pandas as pd
import numpy as np
import yaml
with open('config.yaml', 'r') as stream:
    config = yaml.safe_load(stream)
    clean_scancollection = config['clean_collection_of_scans_per_patient']
    
df = pd.read_csv(clean_scancollection, index_col=0)

# %%
# excluding all non 4D-CT scans from this df:
df = df[df['modality'] == 'CT']

# looking only for percentage description names, because including 4D returns some average scans that do not include the words Averages or MIP
# to check you can use this code: 
        # df[df['series_description'].str.contains('4D')&
        #    ~(df['series_description'].str.contains('\d{1,2}%|Ave|MIP'))]
        
df_4d = df[(df['series_description'].str.contains('\d{1,2}%')) &
           ~(df['series_description'].str.contains('Ave|MIP'))]

# %% [markdown]
# Now we have a df with only 4DCT scan phases. Next step is to make an df with patient id as index and phases as cols using a 1/0 or bool value for present

# %%
df_4d
# Out:
#         modality  study_date RT_startdate study_description  \
# p_id
# 4879          CT  2018-07-26   2018-08-06    RTHE CT THORAX
# 4879          CT  2018-07-26   2018-08-06    RTHE CT THORAX
# 4879          CT  2018-07-26   2018-08-06    RTHE CT THORAX
# 4879          CT  2018-07-26   2018-08-06    RTHE CT THORAX
# 4879          CT  2018-07-26   2018-08-06    RTHE CT THORAX
# ...          ...         ...          ...               ...
# 9949900       CT  2015-04-03   2015-04-13      LUCHTW CT.TH
# 9949900       CT  2015-04-03   2015-04-13      LUCHTW CT.TH
# 9949900       CT  2015-04-03   2015-04-13      LUCHTW CT.TH
# 9949900       CT  2015-04-03   2015-04-13      LUCHTW CT.TH
# 9970729       CT  2015-04-23   2015-05-04      LUCHTW CT.TH
#
#                         series_description  \
# p_id
# 4879       T=0%,PR=95% -> 3%,AR()=26 -> 57
# 4879      T=10%,PR=5% -> 14%,AR()=37 -> 72
# 4879     T=20%,PR=15% -> 24%,AR()=50 -> 87
# 4879     T=30%,PR=25% -> 34%,AR()=62 -> 91
# ...

# %%
import re
x = 'asdf'
'a' in x
# Out:
# True

# %%
phases = pd.DataFrame(index=df_4d.index.unique(), columns=['10%', '20%', '30%', '40%', '50%', '60%', '70%', '80%', '90%'])

for index, row in df_4d.iterrows():
    phases.loc[index, '0%'] = 'T=0%' in row['series_description']
    phases.loc[index, '10%'] = 'T=10%' in row['series_description']
    phases.loc[index, '20%'] = 'T=20%' in row['series_description']
    phases.loc[index, '30%'] = 'T=30%' in row['series_description']
    phases.loc[index, '40%'] = 'T=40%' in row['series_description']
    phases.loc[index, '50%'] = 'T=50%' in row['series_description']
    phases.loc[index, '60%'] = 'T=60%' in row['series_description']
    phases.loc[index, '70%'] = 'T=70%' in row['series_description']
    phases.loc[index, '80%'] = 'T=80%' in row['series_description']
    phases.loc[index, '90%'] = 'T=90%' in row['series_description']
    
        
    # if 'T=10%' in row[''series_description]:
    #     phases.loc[index, '10%'] = True
    # elif 'T=20%' in row[''series_description]:
    #     phases.loc[index, '20%'] = True
    # elif 'T=30%' in row[''series_description]:
    #     phases.loc[index, '30%'] = True
    # elif 'T=40%' in row[''series_description]:
    #     phases.loc[index, '40%'] = True
    # elif 'T=50%' in row[''series_description]:
    #     phases.loc[index, '50%'] = True
    # elif 'T=60%' in row[''series_description]:
    #     phases.loc[index, '60%'] = True
    # elif 'T=70%' in row[''series_description]:
    #     phases.loc[index, '70%'] = True
    # elif 'T=80%' in row[''series_description]:
    #     phases.loc[index, '80%'] = True
    # elif 'T=90%' in row[''series_description]:
    #     phases.loc[index, '90%'] = True
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...
